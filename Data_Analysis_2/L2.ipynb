# %%
import pandas as pd

print(pd.__version__)
# Out:
# 3.0.0

# %%
grades = pd.Series({"Anna": 15, "Nikos": 20, "Kostas": 18})
grades
# Out:
# Anna      15
# Nikos     20
# Kostas    18
# dtype: int64

# %%
grades.iloc[1]
grades.loc["Nikos"]
# Out:
# np.int64(20)

# %%
grades.iloc[:2]
# Out:
# Anna     15
# Nikos    20
# dtype: int64

# %% [markdown]
# # Math on Series

# %%
s1 = pd.Series([10, 20, 30])
s2 = pd.Series([1, 2, 3])

# Scalar operations
s1 + 5
print(s1 * 10)
# Out:
# 0    100
# 1    200
# 2    300
# dtype: int64

# %%
# Vector Operations
s1 + s2
# Out:
# 0    11
# 1    22
# 2    33
# dtype: int64

# %%
grades1 = pd.Series({"Maria": 15, "Nikos": 20, "Kostas": 18})
grades + grades1
# Out:
# Anna       NaN
# Kostas    36.0
# Maria      NaN
# Nikos     40.0
# dtype: float64

# %% [markdown]
# # Series most useful functions

# %%
s1
# Out:
# 0    10
# 1    20
# 2    30
# dtype: int64

# %%
s1.sum()
# Out:
# np.int64(60)

# %%
s1.min()
# Out:
# np.int64(10)

# %%
s1.max()
# Out:
# np.int64(30)

# %%
s1.mean()
# Out:
# np.float64(20.0)

# %%
s1.sum()/len(s1)
# Out:
# np.float64(20.0)

# %%
s1.sort_values(ascending=False)
# Out:
# 2    30
# 1    20
# 0    10
# dtype: int64

# %%
s1.unique()
# Out:
# array([10, 20, 30])

# %%
s3 = pd.Series([10, 10, 20])
s3.value_counts()
# Out:
# 10    2
# 20    1
# Name: count, dtype: int64

# %%
grades
# Out:
# Anna      15
# Nikos     20
# Kostas    18
# dtype: int64

# %%
grades.max()
# Out:
# np.int64(20)

# %%
grades.idxmax()
# Out:
# 'Nikos'

# %%
grades.nunique()
# Out:
# 3

# %%
len(grades.unique())
# Out:
# 3

# %%
# Boolean Mask
grades
boolean_mas = pd.Series([True, False, True])
# Out:
# Anna      15
# Nikos     20
# Kostas    18
# dtype: int64

# %%
grades.isin([15, 20])
# Out:
# Anna       True
# Nikos      True
# Kostas    False
# dtype: bool

# %%
grades[]
# Out:
# Anna     15
# Nikos    20
# dtype: int64

# %%
grades > 16
# Out:
# Anna      False
# Nikos      True
# Kostas     True
# dtype: bool

# %%
grades
# Out:
# Anna      15
# Nikos     20
# Kostas    18
# dtype: int64

# %%
grades[~grades.isin([20])]
# Out:
# Anna      15
# Kostas    18
# dtype: int64

# %%
score = pd.Series(0, ["Kostas", "Anna", 'Mitsos'], name="scores")
score
# Out:
# Kostas    0
# Anna      0
# Mitsos    0
# Name: scores, dtype: int64

# %%
grades
# Out:
# Anna      15
# Nikos     20
# Kostas    18
# dtype: int64

# %%
def pow(x):
    return x**2

grades.map(pow)
# Out:
# Anna      225
# Nikos     400
# Kostas    324
# dtype: int64

# %%
grades
# Out:
# Anna      15
# Nikos     20
# Kostas    18
# dtype: int64

# %%
grades.map()
# Out:
# Anna      15
# Nikos     20
# Kostas    18
# dtype: int64

# %%
# lambda parameters: return_values

# %%
grades.map(lambda x: x**2)
# Out:
# Anna      225
# Nikos     400
# Kostas    324
# dtype: int64

# %%
grades
# Out:
# Anna      15
# Nikos     20
# Kostas    18
# dtype: int64

# %%
grades.map({15: 16, 20:21, 18:19})
# Out:
# Anna      16
# Nikos     21
# Kostas    19
# dtype: int64

# %%
class Series:
    def __init__(self, data):
        self.data = data
        self.dtype = type(data[0])

s = Series([1, 2, 3, 4])

# %%
s.dtype
# Out:
# int

# %%
s = pd.Series()

# %%
data = {
    "Department": ["Sales", "Sales", "HR", "HR", "IT", "IT"],
    "Employee": ["Alice", "Bob", "Charlie", "David", "Eva", "Frank"],
    "Salary": [50000, 60000, 45000, 48000, 70000, 72000]
}

df = pd.DataFrame(data)

# %%
df
# Out:
#   Department Employee  Salary
# 0      Sales    Alice   50000
# 1      Sales      Bob   60000
# 2         HR  Charlie   45000
# 3         HR    David   48000
# 4         IT      Eva   70000
# 5         IT    Frank   72000

# %%
df.columns = ["D", 'E', 'S']
df
# Out:
#        D        E      S
# 0  Sales    Alice  50000
# 1  Sales      Bob  60000
# 2     HR  Charlie  45000
# 3     HR    David  48000
# 4     IT      Eva  70000
# 5     IT    Frank  72000

# %%
data = {
    "Name": ["Alice", "Bob", "Carol", "David", "Eva"],
    "City": ["NY", "Paris", "NY", "Paris", "NY"],
    "Score": [85, 90, 95, 80, 70]
}

df = pd.DataFrame(data)
df
# Out:
#     Name   City  Score
# 0  Alice     NY     85
# 1    Bob  Paris     90
# 2  Carol     NY     95
# 3  David  Paris     80
# 4    Eva     NY     70
