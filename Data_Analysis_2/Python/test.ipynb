# %%
import pandas as pd

# %%
numbers = pd.Series([10, 20, 30, 40, 50])

# %%
numbers.map(lambda i: i**3)
# Out:
# 0      1000
# 1      8000
# 2     27000
# 3     64000
# 4    125000
# dtype: int64

# %%
numbers
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# 4    50
# dtype: int64

# %%
~numbers.isin([20, 30])
# Out:
# 0     True
# 1    False
# 2    False
# 3     True
# 4     True
# dtype: bool

# %%
numbers[~numbers.isin([20, 30])]
# Out:
# 0    10
# 3    40
# 4    50
# dtype: int64

# %%
df = pd.read_excel("misthoi.xlsx", index_col="ID")
df.head()
# Out:
#       Όνομα  Ηλικία         Πόλη  Μισθός
# ID
# 1   Γιάννης      28        Αθήνα    1500
# 2     Μαρία      34  Θεσσαλονίκη    1700
# 3    Κώστας      41        Πάτρα    1600
# 4     Ελένη      29     Ηράκλειο    1550
# 5     Νίκος      37       Λάρισα    1650

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 100 entries, 1 to 100
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Όνομα   100 non-null    str
#  1   Ηλικία  100 non-null    int64
#  2   Πόλη    100 non-null    str
#  3   Μισθός  100 non-null    int64
# dtypes: int64(2), str(2)
# memory usage: 3.3 KB

# %%
df.describe()
# Out:
#            Ηλικία       Μισθός
# count  100.000000   100.000000
# mean    33.870000  1607.500000
# std      5.459964    88.538926
# min     26.000000  1470.000000
# 25%     29.000000  1550.000000
# 50%     33.000000  1600.000000
# 75%     38.000000  1680.000000
# max     45.000000  1800.000000

# %%
df.head()
# Out:
#       Όνομα  Ηλικία         Πόλη  Μισθός
# ID
# 1   Γιάννης      28        Αθήνα    1500
# 2     Μαρία      34  Θεσσαλονίκη    1700
# 3    Κώστας      41        Πάτρα    1600
# 4     Ελένη      29     Ηράκλειο    1550
# 5     Νίκος      37       Λάρισα    1650

# %%
# %pip install seaborn
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import seaborn as sns

# %%
df = sns.load_dataset("tips")

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
df["tip"].sort_values(ascending=False)
# Out:
# 170    10.00
# 212     9.00
# 23      7.58
# 59      6.73
# 141     6.70
#        ...
# 0       1.01
# 236     1.00
# 111     1.00
# 67      1.00
# 92      1.00
# Name: tip, Length: 244, dtype: float64

# %%
df.groupby("sex").agg({"tip": "sum", "size":"mean"})
# Out:
#            tip      size
# sex
# Male    485.07  2.630573
# Female  246.51  2.459770

# %%
test = df.groupby(["sex", "smoker"])["tip"].agg("mean")
test
# Out:
# sex     smoker
# Male    Yes       3.051167
#         No        3.113402
# Female  Yes       2.931515
#         No        2.773519
# Name: tip, dtype: float64

# %%
test.loc["Male", "Yes"]
# Out:
# np.float64(3.0511666666666666)

# %%
data = {
    "Department": ["Sales", "Sales", "HR", "HR", "IT", "IT"],
    "Employee": ["Alice", "Bob", "Charlie", "David", "Eva", "Frank"],
    "Salary": [50000, 60000, 45000, 48000, 70000, 72000]
}

df = pd.DataFrame(data)

# %%
s_multi = df.groupby(["Department", "Employee"])["Salary"].sum()
s_multi
# Out:
# Department  Employee
# HR          Charlie     45000
#             David       48000
# IT          Eva         70000
#             Frank       72000
# Sales       Alice       50000
#             Bob         60000
# Name: Salary, dtype: int64

# %%
s_multi.reset_index()
# Out:
#   Department Employee  Salary
# 0         HR  Charlie   45000
# 1         HR    David   48000
# 2         IT      Eva   70000
# 3         IT    Frank   72000
# 4      Sales    Alice   50000
# 5      Sales      Bob   60000

# %%
import pandas as pd

# %%
data = {"Year": [2020, 2021, 2022, 2023],
        "Sales": [250, 300, 400, 500]}
df = pd.DataFrame(data)

df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Year    4 non-null      int64
#  1   Sales   4 non-null      int64
# dtypes: int64(2)
# memory usage: 196.0 bytes

# %%
df.plot(x="Year", y="Sales", kind="line",marker="o", title="Sales Over Time")
# Out:
# <Axes: title={'center': 'Sales Over Time'}, xlabel='Year'>

# %%
customers = pd.read_csv('data/customers.csv', index_col='CustomerID')
customers
# Out:
#                                    CompanyName             CustomerName  \
# CustomerID
# ALFKI                      Alfreds Futterkiste             Maria Anders
# ANATR       Ana Trujillo Emparedados y helados             Ana Trujillo
# ANTON                  Antonio Moreno Taquería           Antonio Moreno
# AROUT                          Around the Horn             Thomas Hardy
# BERGS                       Berglunds snabbköp       Christina Berglund
# ...                                        ...                      ...
# WARTH                           Wartian Herkku         Pirkko Koskitalo
# WELLI                   Wellington Importadora            Paula Parente
# WHITC                     White Clover Markets           Karl Jablonski
# WILMK                              Wilman Kala          Matti Karttunen
# WOLZA                           Wolski  Zajazd  Zbyszek Piestrzeniewicz
#
#                          ContactTitle                         Address  \
# CustomerID
# ...

# %%
df = pd.DataFrame(customers.groupby("City")['CompanyName'].count().sort_values(ascending=False))
df = df.head(20)
df.plot(kind='barh')
# Out:
# <Axes: ylabel='City'>

# %%
orders = pd.read_csv('data/orders.csv')
orders.plot(x="OrderDate", y="Freight", kind='line')
# Out:
# <Axes: xlabel='OrderDate'>

# %%
orders.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 830 entries, 0 to 829
# Data columns (total 14 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   OrderID         830 non-null    int64
#  1   CustomerID      830 non-null    str
#  2   EmployeeID      830 non-null    int64
#  3   OrderDate       830 non-null    str
#  4   RequiredDate    830 non-null    str
#  5   ShippedDate     809 non-null    str
#  6   ShipVia         830 non-null    int64
#  7   Freight         830 non-null    float64
#  8   ShipName        830 non-null    str
#  9   ShipAddress     830 non-null    str
#  10  ShipCity        830 non-null    str
#  11  ShipRegion      323 non-null    str
#  12  ShipPostalCode  811 non-null    str
#  13  ShipCountry     830 non-null    str
# dtypes: float64(1), int64(3), str(10)
# memory usage: 90.9 KB

# %%
df = pd.DataFrame({
    "date": pd.date_range("2023-01-01", periods=6, freq="D"),
    "sales": [200, 220, 250, 270, 260, 300]
})

df.set_index("date", inplace=True)
df
# Out:
#             sales
# date
# 2023-01-01    200
# 2023-01-02    220
# 2023-01-03    250
# 2023-01-04    270
# 2023-01-05    260
# 2023-01-06    300
