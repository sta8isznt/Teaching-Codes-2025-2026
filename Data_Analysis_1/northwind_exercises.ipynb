# %%
import pandas as pd

# %% [markdown]
# Άσκηση 1

# %%
customers = pd.read_csv("data/customers.csv")
orders = pd.read_csv("data/orders.csv")
employees = pd.read_csv("data/employees.csv")
orderdetails = pd.read_csv("data/orderdetails.csv")
products = pd.read_csv("data/products.csv", index_col="ProductID")
categories = pd.read_csv("data/categories.csv")
suppliers = pd.read_csv("data/suppliers.csv")
shippers = pd.read_csv("data/shippers.csv")

# %%
dfs = {
    "customers": customers,
    "orders": orders,
    "employees": employees,
    "orderdetails": orderdetails,
    "products": products,
    "categories": categories,
    "suppliers": suppliers,
    "shippers": shippers
}

# %% [markdown]
# Άσκηση 2

# %%
for name, df in dfs.items():
    print(f"Table {name} has shape {df.shape}")
# Out:
# Table customers has shape (91, 14)
# Table orders has shape (830, 14)
# Table employees has shape (9, 18)
# Table orderdetails has shape (2155, 5)
# Table products has shape (77, 10)
# Table categories has shape (8, 4)
# Table suppliers has shape (29, 12)
# Table shippers has shape (3, 3)

# %% [markdown]
# Άσκηση 4

# %%
dfs["employees"].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9 entries, 0 to 8
# Data columns (total 18 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   EmployeeID       9 non-null      int64
#  1   LastName         9 non-null      object
#  2   FirstName        9 non-null      object
#  3   Title            9 non-null      object
#  4   TitleOfCourtesy  9 non-null      object
#  5   BirthDate        9 non-null      object
#  6   HireDate         9 non-null      object
#  7   Salary           9 non-null      int64
#  8   Address          9 non-null      object
#  9   City             9 non-null      object
#  10  Region           5 non-null      object
#  11  PostalCode       9 non-null      object
#  12  Country          9 non-null      object
#  13  HomePhone        9 non-null      object
#  14  Extension        9 non-null      int64
#  15  Photo            9 non-null      object
#  16  Notes            9 non-null      object
# ...

# %%
dfs["employees"].dtypes
# Out:
# EmployeeID           int64
# LastName            object
# FirstName           object
# Title               object
# TitleOfCourtesy     object
# BirthDate           object
# HireDate            object
# Salary               int64
# Address             object
# City                object
# Region              object
# PostalCode          object
# Country             object
# HomePhone           object
# Extension            int64
# Photo               object
# Notes               object
# ReportsTo          float64
# dtype: object

# %% [markdown]
# Άσκηση 5

# %%
dfs["customers"].isna().sum()
# Out:
# CustomerID         0
# CompanyName        0
# CustomerName       0
# ContactTitle       0
# Address            0
# City               0
# Region            60
# PostalCode         1
# Country            0
# Phone              0
# Fax               22
# Image             91
# ImageThumbnail    91
# age               91
# dtype: int64

# %%
# Drop
dfs["customers"].drop(["Image", "ImageThumbnail", "age"], axis=1, inplace=True)

# %%
dfs["customers"].isna().sum()
# Out:
# CustomerID       0
# CompanyName      0
# CustomerName     0
# ContactTitle     0
# Address          0
# City             0
# Region          60
# PostalCode       1
# Country          0
# Phone            0
# Fax             22
# dtype: int64

# %% [markdown]
# Άσκηση 6

# %%
dfs["customers"].Country.nunique()
# Out:
# 21

# %% [markdown]
# Άσκηση 7

# %%
dfs["products"][["ProductName", "Price"]]
# Out:
#                                ProductName  Price
# ProductID
# 1                                     Chai  18.00
# 2                                    Chang  19.00
# 3                            Aniseed Syrup  10.00
# 4             Chef Anton's Cajun Seasoning  22.00
# 5                   Chef Anton's Gumbo Mix  21.35
# ...                                    ...    ...
# 73                              Röd Kaviar  15.00
# 74                           Longlife Tofu  10.00
# 75                    Rhönbräu Klosterbier   7.75
# 76                            Lakkalikööri  18.00
# 77         Original Frankfurter grüne Soße  13.00
#
# [77 rows x 2 columns]

# %%
customers[["CompanyName", "Country", "City"]].iloc[[0, 3, 5]]
# Out:
#                CompanyName  Country      City
# 0      Alfreds Futterkiste  Germany    Berlin
# 3          Around the Horn       UK    London
# 5  Blauer See Delikatessen  Germany  Mannheim

# %%
orders.iloc[:4, :6]
# Out:
#    OrderID CustomerID  EmployeeID            OrderDate         RequiredDate  \
# 0    10248      VINET           5  1994-08-04 00:00:00  1994-09-01 00:00:00
# 1    10249      TOMSP           6  1994-08-05 00:00:00  1994-09-16 00:00:00
# 2    10250      HANAR           4  1994-08-08 00:00:00  1994-09-05 00:00:00
# 3    10251      VICTE           3  1994-08-08 00:00:00  1994-09-05 00:00:00
#
#            ShippedDate
# 0  1994-08-16 00:00:00
# 1  1994-08-10 00:00:00
# 2  1994-08-12 00:00:00
# 3  1994-08-15 00:00:00

# %%
customers[(customers.Country == "Germany") | (customers.Country == "France")]
# Out:
#    CustomerID                CompanyName         CustomerName  \
# 0       ALFKI        Alfreds Futterkiste         Maria Anders
# 5       BLAUS    Blauer See Delikatessen           Hanna Moos
# 6       BLONP       Blondel père et fils   Frédérique Citeaux
# 8       BONAP                    Bon app     Laurence Lebihan
# 16      DRACD   Drachenblut Delikatessen         Sven Ottlieb
# 17      DUMON            Du monde entier       Janine Labrune
# 22      FOLIG          Folies gourmandes        Martine Rancé
# 24      FRANK             Frankenversand        Peter Franken
# 25      FRANR        France restauration       Carine Schmitt
# 38      KOENE            Königlich Essen        Philip Cramer
# 39      LACOR       La corne d'abondance        Daniel Tonini
# 40      LAMAI           La maison d'Asie       Annette Roulet
# 43      LEHMS        Lehmanns Marktstand       Renate Messner
# 51      MORGK     Morgenstern Gesundkost      Alexander Feuer
# ...

# %%
customers[customers.Country.isin(["Germany", "France", "Brazil"])]
# Out:
#    CustomerID                CompanyName         CustomerName  \
# 0       ALFKI        Alfreds Futterkiste         Maria Anders
# 5       BLAUS    Blauer See Delikatessen           Hanna Moos
# 6       BLONP       Blondel père et fils   Frédérique Citeaux
# 8       BONAP                    Bon app     Laurence Lebihan
# 14      COMMI           Comércio Mineiro         Pedro Afonso
# 16      DRACD   Drachenblut Delikatessen         Sven Ottlieb
# 17      DUMON            Du monde entier       Janine Labrune
# 20      FAMIA         Familia Arquibaldo            Aria Cruz
# 22      FOLIG          Folies gourmandes        Martine Rancé
# 24      FRANK             Frankenversand        Peter Franken
# 25      FRANR        France restauration       Carine Schmitt
# 30      GOURL        Gourmet Lanchonetes        André Fonseca
# 33      HANAR              Hanari Carnes         Mario Pontes
# 38      KOENE            Königlich Essen        Philip Cramer
# ...
